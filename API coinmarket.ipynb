# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '1b1c9e63-1dc9-454e-84d5-34397c9b896d',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-10-18T09:43:07.739Z', 'error_code': 0, 'error_message': None, 'elapsed': 0, 'credit_count': 1, 'notice': None}, 'data': [{'id': 741, 'name': '9ud7d9m2txe', 'symbol': 'af0ilb1gxkr', 'slug': 'q6ljd4pjlmd', 'cmc_rank': 2090, 'num_market_pairs': 8322, 'circulating_supply': 6765, 'total_supply': 2876, 'max_supply': 7782, 'infinite_supply': None, 'last_updated': '2023-10-18T09:43:07.739Z', 'date_added': '2023-10-18T09:43:07.739Z', 'tags': ['7p04nbkblom', '1zj5yl0lbvw', 'ec95hvfsl6', 'c88lk2fgya9', 'vom58f0zml8', 'lalz1bmf8qi', 'ldfiz11v2ah', 'r6f4jamdmb', 's033ntu3mvq', '7k3nz9fbnu9'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.5089059401516556, 'volume_24h': 3166, 'volume_change_24h': 0.8828052518369771, 'percent_change_1h': 0.43909868626974746, 'percent_change_24h': 0.37537407202677864, 'percent_change_7d': 0.07124555218143946, 'market_cap': 0.09842519978696007, 'market_cap_domi
# ...

# %%
type("data")
# Out:
# str

# %%
import pandas as pd 
df = pd.json_normalize(data['data'])

# %%
df
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0   741  9ud7d9m2txe  af0ilb1gxkr  q6ljd4pjlmd      2090              8322
# 1  6303  3bn723955qo   y1ji29lwf4   q2yidhzbh1      6617              2922
# 2  4980   jqjvc55grr   natt7flpzo   loemhd820l      8460              7330
# 3  9707   ih1j6uj1pi  flpzau6f9ks   vyczxd545v       294              2200
# 4  4592  ioewsruzk1e   y3v80evuyy   mocx9h2rpa      5821              8820
# 5  4116  ewxsxd23koo  jzgn62w0wkk  ye6xppqxnag      6645              7229
# 6  4518  54plzc2xuus   pufk7pqvtd  81tjklq18wg      8700              2011
# 7  2415  lw7p0cni4ga  fkxhhfoh94a  dx3e6k0ar8w      5293              4168
# 8  5506  zcq0cf6cb6f  mb9axeif51s   bcte7xcfjs      5656              4715
# 9  3801   yg6bb4v0qw  vwrl2sg58vh  ov80avvmmwo       217              7253
#
#    circulating_supply  total_supply  max_supply infinite_supply  \
# 0                6765          2876        7782            None
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
df['timestamp']=pd.to_datetime('now')
# Out:
# C:\Users\ThisPC\AppData\Local\Temp\ipykernel_17912\2182407126.py:1: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp']=pd.to_datetime('now')

# %%
df
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0   741  9ud7d9m2txe  af0ilb1gxkr  q6ljd4pjlmd      2090              8322
# 1  6303  3bn723955qo   y1ji29lwf4   q2yidhzbh1      6617              2922
# 2  4980   jqjvc55grr   natt7flpzo   loemhd820l      8460              7330
# 3  9707   ih1j6uj1pi  flpzau6f9ks   vyczxd545v       294              2200
# 4  4592  ioewsruzk1e   y3v80evuyy   mocx9h2rpa      5821              8820
# 5  4116  ewxsxd23koo  jzgn62w0wkk  ye6xppqxnag      6645              7229
# 6  4518  54plzc2xuus   pufk7pqvtd  81tjklq18wg      8700              2011
# 7  2415  lw7p0cni4ga  fkxhhfoh94a  dx3e6k0ar8w      5293              4168
# 8  5506  zcq0cf6cb6f  mb9axeif51s   bcte7xcfjs      5656              4715
# 9  3801   yg6bb4v0qw  vwrl2sg58vh  ov80avvmmwo       217              7253
#
#    circulating_supply  total_supply  max_supply infinite_supply  \
# 0                6765          2876        7782            None
# ...

# %%
def api_runner ():
    global df 
    from requests import Request, Session
    from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
    import json

    url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'}

    
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '1b1c9e63-1dc9-454e-84d5-34397c9b896d',
}

    session = Session()
    session.headers.update(headers)

    try:
       response = session.get(url, params=parameters)
       data = json.loads(response.text)
       print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
       print(e)
    import pandas as pd 
    df = pd.json_normalize(data['data'])
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', None)
    df['timestamp']=pd.to_datetime('now')
   
    if not os.path.isfile(r'C:\Users\ThisPC\OneDrive\Desktop\My Projects\API.csv'):
        df.to_csv(r'C:\Users\ThisPC\OneDrive\Desktop\My Projects\API.csv',header =True)
    else:
        df.to_csv(r'C:\Users\ThisPC\OneDrive\Desktop\My Projects\API.csv',mode ='a',header =False)

# %%
df
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0   741  9ud7d9m2txe  af0ilb1gxkr  q6ljd4pjlmd      2090              8322
# 1  6303  3bn723955qo   y1ji29lwf4   q2yidhzbh1      6617              2922
# 2  4980   jqjvc55grr   natt7flpzo   loemhd820l      8460              7330
# 3  9707   ih1j6uj1pi  flpzau6f9ks   vyczxd545v       294              2200
# 4  4592  ioewsruzk1e   y3v80evuyy   mocx9h2rpa      5821              8820
# 5  4116  ewxsxd23koo  jzgn62w0wkk  ye6xppqxnag      6645              7229
# 6  4518  54plzc2xuus   pufk7pqvtd  81tjklq18wg      8700              2011
# 7  2415  lw7p0cni4ga  fkxhhfoh94a  dx3e6k0ar8w      5293              4168
# 8  5506  zcq0cf6cb6f  mb9axeif51s   bcte7xcfjs      5656              4715
# 9  3801   yg6bb4v0qw  vwrl2sg58vh  ov80avvmmwo       217              7253
#
#    circulating_supply  total_supply  max_supply infinite_supply  \
# 0                6765          2876        7782            None
# ...

# %%
import os
from time import time 
from time import sleep
for i in range(333):
    api_runner ()
    print('api_runner completed')
    sleep(60)
exit()

# %%
df
# Out:
#      id          name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  1097    zwm5rltep7   vll5uif9tf  8n78inu7dwq      7805              9146
# 1   752   c942yc7cnfl  83e78k1adci   msunf6eab6       766              8626
# 2  5710   w00lazead3a   ndt8vb88qb  loeqpz8tinl      7276              4629
# 3  6944  01b8edklyvsu  xkq1hzmqgzs  mb5godu2kig      6227              2123
# 4  1935   84dgeb9v3z4  5f40u4ol8kx  ksf4hvvkbzc      2870              6590
# 5  9295   90ox19zgqfk  z1twbi4ix6l   ok722mnfz4      1928              2846
# 6  8053    zqep3i7a2y   tjaw8ie2j3  u672biah6th      3026              5996
# 7  6009   htnh0pmmq1a  qnuqx0i97ae  81yetyqucrq      5950              3761
# 8  8244   wbjgtfsbzmh  he4nhotdro6   b7v93xrkbm      2104              9617
# 9  8217   m8h09n0ckal  qqb0f37965q  wrgklvj60y9       684              3064
#
#    circulating_supply  total_supply  max_supply infinite_supply  \
# 0                3777          4309         830            None
# ...

# %%
df7=pd.read_csv(r'c:\Users\ThisPC\OneDrive\Desktop\My Projects\API.csv')

# %%
df7
# Out:
#     Unnamed: 0    id          name        symbol         slug  cmc_rank  \
# 0            0  1810  0lks97yhl09r  0z92d3bic8zf   iog21dso98      9545
# 1            1  2376    l5jfptwgxp    tj2im6248c  o79e4pjcref       979
# 2            2  8059    mybh5phwe6   v476yrbtbgr  7lzljxri1tj      8279
# 3            3  3962   fjwnh3k1sbp    syodgr3tk2  z2xb4gtsjhq      2515
# 4            4  7094    zuxu7pt8zf    ny0gejnv6i  20hftnjcaut      9242
# 5            5  7873    ic0immcozb    q2v1cmxxg6   x3vrkk2ak3      5985
# 6            6  8606   8vnc29rsp2x   pdruk1lr2xj  dm4s0wcjba9      2084
# 7            7  4649   gjt7i7aw99o   aog5m7jcm28  n8w4fhscaln      4598
# 8            8  1614   5a7c956ylwe    z3oocu2cjf  m5i8e07ljlf        15
# 9            9  4145  0c8nizm0lo6d   v03ad2hozj8  x9deo7ypwkk      8940
# 10           0  8992   6lirp1f9zju   6e4p61em1w9  b5k58bgd9gt      9712
# 11           1  5910   1rrktova9t3    e1y4yau8ce  ntbbikcegia      8282
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df7
# Out:
#     Unnamed: 0    id          name        symbol         slug  cmc_rank  \
# 0            0  1810  0lks97yhl09r  0z92d3bic8zf   iog21dso98      9545
# 1            1  2376    l5jfptwgxp    tj2im6248c  o79e4pjcref       979
# 2            2  8059    mybh5phwe6   v476yrbtbgr  7lzljxri1tj      8279
# 3            3  3962   fjwnh3k1sbp    syodgr3tk2  z2xb4gtsjhq      2515
# 4            4  7094    zuxu7pt8zf    ny0gejnv6i  20hftnjcaut      9242
# 5            5  7873    ic0immcozb    q2v1cmxxg6   x3vrkk2ak3      5985
# 6            6  8606   8vnc29rsp2x   pdruk1lr2xj  dm4s0wcjba9      2084
# 7            7  4649   gjt7i7aw99o   aog5m7jcm28  n8w4fhscaln      4598
# 8            8  1614   5a7c956ylwe    z3oocu2cjf  m5i8e07ljlf        15
# 9            9  4145  0c8nizm0lo6d   v03ad2hozj8  x9deo7ypwkk      8940
# 10           0  8992   6lirp1f9zju   6e4p61em1w9  b5k58bgd9gt      9712
# 11           1  5910   1rrktova9t3    e1y4yau8ce  ntbbikcegia      8282
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d']].mean()
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# zwm5rltep7                        0.86740                       0.56997
# c942yc7cnfl                       0.84431                       0.04188
# w00lazead3a                       0.93718                       0.21468
# 01b8edklyvsu                      0.26887                       0.90943
# 84dgeb9v3z4                       0.21899                       0.72535
# 90ox19zgqfk                       0.50661                       0.18252
# zqep3i7a2y                        0.93748                       0.80390
# htnh0pmmq1a                       0.90178                       0.38222
# wbjgtfsbzmh                       0.34508                       0.02536
# m8h09n0ckal                       0.26900                       0.51609
#
#               quote.USD.percent_change_7d
# name
# zwm5rltep7                        0.90201
# c942yc7cnfl                       0.51855
# ...

# %%
df4 =df3.stack()

# %%
df4
# Out:
# name
# zwm5rltep7    quote.USD.percent_change_1h    0.86740
#               quote.USD.percent_change_24h   0.56997
#               quote.USD.percent_change_7d    0.90201
# c942yc7cnfl   quote.USD.percent_change_1h    0.84431
#               quote.USD.percent_change_24h   0.04188
#               quote.USD.percent_change_7d    0.51855
# w00lazead3a   quote.USD.percent_change_1h    0.93718
#               quote.USD.percent_change_24h   0.21468
#               quote.USD.percent_change_7d    0.28142
# 01b8edklyvsu  quote.USD.percent_change_1h    0.26887
#               quote.USD.percent_change_24h   0.90943
#               quote.USD.percent_change_7d    0.30810
# 84dgeb9v3z4   quote.USD.percent_change_1h    0.21899
#               quote.USD.percent_change_24h   0.72535
#               quote.USD.percent_change_7d    0.85300
# 90ox19zgqfk   quote.USD.percent_change_1h    0.50661
#               quote.USD.percent_change_24h   0.18252
#               quote.USD.percent_change_7d    0.65549
# ...

# %%
df5 = df4.to_frame(name ='values')
df5
# Out:
#                                            values
# name
# zwm5rltep7   quote.USD.percent_change_1h  0.86740
#              quote.USD.percent_change_24h 0.56997
#              quote.USD.percent_change_7d  0.90201
# c942yc7cnfl  quote.USD.percent_change_1h  0.84431
#              quote.USD.percent_change_24h 0.04188
#              quote.USD.percent_change_7d  0.51855
# w00lazead3a  quote.USD.percent_change_1h  0.93718
#              quote.USD.percent_change_24h 0.21468
#              quote.USD.percent_change_7d  0.28142
# 01b8edklyvsu quote.USD.percent_change_1h  0.26887
#              quote.USD.percent_change_24h 0.90943
#              quote.USD.percent_change_7d  0.30810
# 84dgeb9v3z4  quote.USD.percent_change_1h  0.21899
#              quote.USD.percent_change_24h 0.72535
#              quote.USD.percent_change_7d  0.85300
# 90ox19zgqfk  quote.USD.percent_change_1h  0.50661
#              quote.USD.percent_change_24h 0.18252
#              quote.USD.percent_change_7d  0.65549
# ...

# %%
df5.count()
# Out:
# values    30
# dtype: int64

# %%
index = pd.Index(range(30))
df6 = df5.set_index(index)

df6 =df5.reset_index()

# %%
df6
# Out:
#             name                       level_1  values
# 0     zwm5rltep7   quote.USD.percent_change_1h 0.86740
# 1     zwm5rltep7  quote.USD.percent_change_24h 0.56997
# 2     zwm5rltep7   quote.USD.percent_change_7d 0.90201
# 3    c942yc7cnfl   quote.USD.percent_change_1h 0.84431
# 4    c942yc7cnfl  quote.USD.percent_change_24h 0.04188
# 5    c942yc7cnfl   quote.USD.percent_change_7d 0.51855
# 6    w00lazead3a   quote.USD.percent_change_1h 0.93718
# 7    w00lazead3a  quote.USD.percent_change_24h 0.21468
# 8    w00lazead3a   quote.USD.percent_change_7d 0.28142
# 9   01b8edklyvsu   quote.USD.percent_change_1h 0.26887
# 10  01b8edklyvsu  quote.USD.percent_change_24h 0.90943
# 11  01b8edklyvsu   quote.USD.percent_change_7d 0.30810
# 12   84dgeb9v3z4   quote.USD.percent_change_1h 0.21899
# 13   84dgeb9v3z4  quote.USD.percent_change_24h 0.72535
# 14   84dgeb9v3z4   quote.USD.percent_change_7d 0.85300
# 15   90ox19zgqfk   quote.USD.percent_change_1h 0.50661
# ...

# %%
df7 = df6.rename(columns={'level_1':'percent_change'})

# %%
df7
# Out:
#             name                percent_change  values
# 0     zwm5rltep7   quote.USD.percent_change_1h 0.86740
# 1     zwm5rltep7  quote.USD.percent_change_24h 0.56997
# 2     zwm5rltep7   quote.USD.percent_change_7d 0.90201
# 3    c942yc7cnfl   quote.USD.percent_change_1h 0.84431
# 4    c942yc7cnfl  quote.USD.percent_change_24h 0.04188
# 5    c942yc7cnfl   quote.USD.percent_change_7d 0.51855
# 6    w00lazead3a   quote.USD.percent_change_1h 0.93718
# 7    w00lazead3a  quote.USD.percent_change_24h 0.21468
# 8    w00lazead3a   quote.USD.percent_change_7d 0.28142
# 9   01b8edklyvsu   quote.USD.percent_change_1h 0.26887
# 10  01b8edklyvsu  quote.USD.percent_change_24h 0.90943
# 11  01b8edklyvsu   quote.USD.percent_change_7d 0.30810
# 12   84dgeb9v3z4   quote.USD.percent_change_1h 0.21899
# 13   84dgeb9v3z4  quote.USD.percent_change_24h 0.72535
# 14   84dgeb9v3z4   quote.USD.percent_change_7d 0.85300
# 15   90ox19zgqfk   quote.USD.percent_change_1h 0.50661
# ...

# %%
df7['percent_change']=df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d'],['1hr','24hr','7d'])
df7
# Out:
#             name percent_change  values
# 0     zwm5rltep7            1hr 0.86740
# 1     zwm5rltep7           24hr 0.56997
# 2     zwm5rltep7             7d 0.90201
# 3    c942yc7cnfl            1hr 0.84431
# 4    c942yc7cnfl           24hr 0.04188
# 5    c942yc7cnfl             7d 0.51855
# 6    w00lazead3a            1hr 0.93718
# 7    w00lazead3a           24hr 0.21468
# 8    w00lazead3a             7d 0.28142
# 9   01b8edklyvsu            1hr 0.26887
# 10  01b8edklyvsu           24hr 0.90943
# 11  01b8edklyvsu             7d 0.30810
# 12   84dgeb9v3z4            1hr 0.21899
# 13   84dgeb9v3z4           24hr 0.72535
# 14   84dgeb9v3z4             7d 0.85300
# 15   90ox19zgqfk            1hr 0.50661
# 16   90ox19zgqfk           24hr 0.18252
# 17   90ox19zgqfk             7d 0.65549
# 18    zqep3i7a2y            1hr 0.93748
# 19    zqep3i7a2y           24hr 0.80390
# 20    zqep3i7a2y             7d 0.59517
# 21   htnh0pmmq1a            1hr 0.90178
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.catplot(x='percent_change',y='values',data =df7,hue ='name',kind='point')

# %%
df10 =df[['name','quote.USD.price','timestamp']]

# %%
df10
# Out:
#            name  quote.USD.price                  timestamp
# 0    zwm5rltep7          0.64378 2023-10-18 09:46:40.534730
# 1   c942yc7cnfl          0.48156 2023-10-18 09:46:40.534730
# 2   w00lazead3a          0.85584 2023-10-18 09:46:40.534730
# 3  01b8edklyvsu          0.33810 2023-10-18 09:46:40.534730
# 4   84dgeb9v3z4          0.96906 2023-10-18 09:46:40.534730
# 5   90ox19zgqfk          0.95917 2023-10-18 09:46:40.534730
# 6    zqep3i7a2y          0.90887 2023-10-18 09:46:40.534730
# 7   htnh0pmmq1a          0.62806 2023-10-18 09:46:40.534730
# 8   wbjgtfsbzmh          0.01404 2023-10-18 09:46:40.534730
# 9   m8h09n0ckal          0.96211 2023-10-18 09:46:40.534730

# %%
df10 =df10.query("name =='wbjgtfsbzmh'")
df10
# Out:
#           name  quote.USD.price                  timestamp
# 8  wbjgtfsbzmh          0.01404 2023-10-18 09:46:40.534730

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x='name',y='quote.USD.price',data = df10)
# Out:
# <Axes: xlabel='name', ylabel='quote.USD.price'>
